# %% [markdown]
# <a href="https://colab.research.google.com/github/farhanasajeer/Python-packages/blob/main/pdexmple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from numpy.random import randn
df=pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# A  0.097824  0.703278 -0.696887  0.705894
# B -0.370058 -0.193182  0.530907  1.220338
# C -2.222227 -0.970113 -0.308194  0.395564
# D  0.774721 -0.148042 -0.305794 -0.064584
# E -0.639739  0.190673 -1.220849 -0.126867

# %%
df['W']>0
# Out:
# A     True
# B    False
# C    False
# D     True
# E    False
# Name: W, dtype: bool

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# A  0.097824  0.703278 -0.696887  0.705894
# D  0.774721 -0.148042 -0.305794 -0.064584

# %%
df.loc

# %%
df.head()
# Out:
#           W         X         Y         Z
# A  0.097824  0.703278 -0.696887  0.705894
# B -0.370058 -0.193182  0.530907  1.220338
# C -2.222227 -0.970113 -0.308194  0.395564
# D  0.774721 -0.148042 -0.305794 -0.064584
# E -0.639739  0.190673 -1.220849 -0.126867

# %%
df.tail()
# Out:
#           W         X         Y         Z
# A  0.097824  0.703278 -0.696887  0.705894
# B -0.370058 -0.193182  0.530907  1.220338
# C -2.222227 -0.970113 -0.308194  0.395564
# D  0.774721 -0.148042 -0.305794 -0.064584
# E -0.639739  0.190673 -1.220849 -0.126867

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.describe()
# Out:
#               A         B    C         E
# count  4.000000  3.000000  0.0  2.000000
# mean   2.500000  5.333333  NaN  8.500000
# std    1.290994  1.527525  NaN  0.707107
# min    1.000000  4.000000  NaN  8.000000
# 25%    1.750000  4.500000  NaN  8.250000
# 50%    2.500000  5.000000  NaN  8.500000
# 75%    3.250000  6.000000  NaN  8.750000
# max    4.000000  7.000000  NaN  9.000000

# %%
df.isnull()
# Out:
#        W      X      Y      Z
# A  False  False  False  False
# B  False  False  False  False
# C  False  False  False  False
# D  False  False  False  False
# E  False  False  False  False

# %%
df.mean()
# Out:
# W   -0.471896
# X   -0.083477
# Y   -0.400163
# Z    0.426069
# dtype: float64

# %%
df.std()
# Out:
# W    1.115889
# X    0.611651
# Y    0.641449
# Z    0.560485
# dtype: float64

# %%
df.var()
# Out:
# W    1.245208
# X    0.374117
# Y    0.411457
# Z    0.314144
# dtype: float64

# %%
df.apply(np.cumsum)
# Out:
#           W         X         Y         Z
# A  0.097824  0.703278 -0.696887  0.705894
# B -0.272234  0.510097 -0.165980  1.926232
# C -2.494460 -0.460016 -0.474174  2.321796
# D -1.719740 -0.608058 -0.779968  2.257212
# E -2.359479 -0.417385 -2.000817  2.130345

# %%
df.value_counts()
# Out:
# W          X          Y          Z
#  0.774721  -0.148042  -0.305794  -0.064584    1
#  0.097824   0.703278  -0.696887   0.705894    1
# -0.370058  -0.193182   0.530907   1.220338    1
# -0.639739   0.190673  -1.220849  -0.126867    1
# -2.222227  -0.970113  -0.308194   0.395564    1
# dtype: int64

# %%
df=pd.DataFrame({'A':[1,2,3,4],
                 'B':[4,5,np.nan,7],
                 'C':[np.nan,np.nan,np.nan,np.nan],
                 'D':['a','b','c','d'],
                 'E':[8,9,np.nan,np.nan]})
df
# Out:
#    A    B   C  D    E
# 0  1  4.0 NaN  a  8.0
# 1  2  5.0 NaN  b  9.0
# 2  3  NaN NaN  c  NaN
# 3  4  7.0 NaN  d  NaN

# %%
df.isnull()
# Out:
#        A      B     C      D      E
# 0  False  False  True  False  False
# 1  False  False  True  False  False
# 2  False   True  True  False   True
# 3  False  False  True  False   True

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []

# %%
df.loc[0]
# Out:
# A      1
# B      4
# C    NaN
# D      a
# E      8
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# A      2
# B      5
# C    NaN
# D      b
# E      9
# Name: 1, dtype: object

# %%
df[]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-0862243bd824> in <module>()
# ----> 1 df['Y'].unique
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Y'
